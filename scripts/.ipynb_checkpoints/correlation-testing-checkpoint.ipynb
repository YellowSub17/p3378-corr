# %%
from extra_data import open_run
import scorpy

# %%
# Load geometry from CrystFEL format file
from extra_geom import AGIPD_1MGeometry
from pyFAI.integrator.azimuthal import AzimuthalIntegrator
import numpy as np
geom = AGIPD_1MGeometry.from_crystfel_geom("/gpfs/exfel/exp/SPB/202304/p003378/scratch/geometry/2023_04_05-p3378_final.geom")



# Generate a simple pattern with a sharper ring and a broader one
px, py, pz = np.moveaxis(geom.get_pixel_positions(), -1, 0)

r = np.sqrt((px ** 2) + (py ** 2))

a1, b1, c1 = 1, 0.15, 0.08
a2, b2, c2 = 1, 0.06, 0.002
frame = (
    a1 * np.exp(- ((r-b1) ** 2) / (2 * c1 ** 2)) +
    a2 * np.exp(- ((r-b2) ** 2) / (2 * c2 ** 2))
)
geom.plot_data_fast(frame)
# Out:
# WARNING:silx.opencl.common:Unable to import pyOpenCl. Please install it from: https://pypi.org/project/pyopencl
# <Axes: xlabel='pixels', ylabel='pixels'>

# %%
ai = AzimuthalIntegrator(
    detector=geom.to_pyfai_detector(),
    dist=0.2,  # sample-detector distance (m)
    wavelength=(12.3984 / 9.3) * 1e-10  # wavelength (m)
)

# %%
ai = AzimuthalIntegrator(
    detector=geom.to_pyfai_detector(),
    dist=0.122,  # sample-detector distance (m)
    wavelength=(12.3984 / 9.3) * 1e-10  # wavelength (m)
)

I, rint2d, chi = ai.integrate2d(
    frame.reshape(16*256, 256),
    300,
    360,
    method='csc'
)

plt.figure(figsize=(6, 8))
plt.imshow(I, aspect='auto',
          extent=(rint2d[0], rint2d[-1], -180, 180))
plt.xlabel('radius (mm)')
plt.ylabel('chi (degrees)')
# Out:
# WARNING:bilinear:Overflow on dim2: d2= 129.5, f2=129.0, p2=129, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 129.5, f2=129.0, p2=129, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 129.5, f2=129.0, p2=129, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 129.5, f2=129.0, p2=129, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 130.5, f2=130.0, p2=130, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 130.5, f2=130.0, p2=130, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 130.5, f2=130.0, p2=130, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 130.5, f2=130.0, p2=130, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 131.5, f2=131.0, p2=131, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 131.5, f2=131.0, p2=131, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 131.5, f2=131.0, p2=131, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 131.5, f2=131.0, p2=131, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 132.5, f2=132.0, p2=132, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 132.5, f2=132.0, p2=132, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 132.5, f2=132.0, p2=132, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 132.5, f2=132.0, p2=132, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 133.5, f2=133.0, p2=133, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 133.5, f2=133.0, p2=133, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 133.5, f2=133.0, p2=133, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 133.5, f2=133.0, p2=133, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 134.5, f2=134.0, p2=134, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 134.5, f2=134.0, p2=134, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 134.5, f2=134.0, p2=134, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 134.5, f2=134.0, p2=134, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 135.5, f2=135.0, p2=135, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 135.5, f2=135.0, p2=135, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 135.5, f2=135.0, p2=135, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 135.5, f2=135.0, p2=135, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 136.5, f2=136.0, p2=136, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 136.5, f2=136.0, p2=136, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 136.5, f2=136.0, p2=136, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 136.5, f2=136.0, p2=136, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 137.5, f2=137.0, p2=137, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 137.5, f2=137.0, p2=137, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 137.5, f2=137.0, p2=137, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 137.5, f2=137.0, p2=137, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 138.5, f2=138.0, p2=138, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 138.5, f2=138.0, p2=138, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 138.5, f2=138.0, p2=138, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 138.5, f2=138.0, p2=138, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 139.5, f2=139.0, p2=139, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 139.5, f2=139.0, p2=139, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 139.5, f2=139.0, p2=139, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 139.5, f2=139.0, p2=139, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 140.5, f2=140.0, p2=140, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 140.5, f2=140.0, p2=140, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 140.5, f2=140.0, p2=140, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 140.5, f2=140.0, p2=140, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 141.5, f2=141.0, p2=141, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 141.5, f2=141.0, p2=141, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 141.5, f2=141.0, p2=141, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 141.5, f2=141.0, p2=141, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 142.5, f2=142.0, p2=142, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 142.5, f2=142.0, p2=142, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 142.5, f2=142.0, p2=142, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 142.5, f2=142.0, p2=142, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 143.5, f2=143.0, p2=143, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 143.5, f2=143.0, p2=143, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 143.5, f2=143.0, p2=143, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 143.5, f2=143.0, p2=143, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 144.5, f2=144.0, p2=144, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 144.5, f2=144.0, p2=144, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 144.5, f2=144.0, p2=144, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 144.5, f2=144.0, p2=144, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 145.5, f2=145.0, p2=145, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 145.5, f2=145.0, p2=145, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 145.5, f2=145.0, p2=145, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 145.5, f2=145.0, p2=145, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 146.5, f2=146.0, p2=146, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 146.5, f2=146.0, p2=146, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 146.5, f2=146.0, p2=146, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 146.5, f2=146.0, p2=146, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 147.5, f2=147.0, p2=147, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 147.5, f2=147.0, p2=147, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 147.5, f2=147.0, p2=147, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 147.5, f2=147.0, p2=147, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 148.5, f2=148.0, p2=148, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 148.5, f2=148.0, p2=148, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 148.5, f2=148.0, p2=148, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 148.5, f2=148.0, p2=148, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 149.5, f2=149.0, p2=149, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 149.5, f2=149.0, p2=149, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 149.5, f2=149.0, p2=149, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 149.5, f2=149.0, p2=149, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 150.5, f2=150.0, p2=150, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 150.5, f2=150.0, p2=150, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 150.5, f2=150.0, p2=150, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 150.5, f2=150.0, p2=150, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 151.5, f2=151.0, p2=151, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 151.5, f2=151.0, p2=151, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 151.5, f2=151.0, p2=151, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 151.5, f2=151.0, p2=151, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 152.5, f2=152.0, p2=152, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 152.5, f2=152.0, p2=152, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 152.5, f2=152.0, p2=152, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 152.5, f2=152.0, p2=152, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 153.5, f2=153.0, p2=153, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 153.5, f2=153.0, p2=153, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 153.5, f2=153.0, p2=153, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 153.5, f2=153.0, p2=153, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 154.5, f2=154.0, p2=154, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 154.5, f2=154.0, p2=154, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 154.5, f2=154.0, p2=154, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 154.5, f2=154.0, p2=154, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 155.5, f2=155.0, p2=155, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 155.5, f2=155.0, p2=155, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 155.5, f2=155.0, p2=155, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 155.5, f2=155.0, p2=155, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 156.5, f2=156.0, p2=156, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 156.5, f2=156.0, p2=156, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 156.5, f2=156.0, p2=156, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 156.5, f2=156.0, p2=156, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 157.5, f2=157.0, p2=157, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 157.5, f2=157.0, p2=157, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 157.5, f2=157.0, p2=157, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 157.5, f2=157.0, p2=157, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 158.5, f2=158.0, p2=158, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 158.5, f2=158.0, p2=158, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 158.5, f2=158.0, p2=158, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 158.5, f2=158.0, p2=158, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 159.5, f2=159.0, p2=159, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 159.5, f2=159.0, p2=159, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 159.5, f2=159.0, p2=159, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 159.5, f2=159.0, p2=159, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 160.5, f2=160.0, p2=160, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 160.5, f2=160.0, p2=160, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 160.5, f2=160.0, p2=160, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 160.5, f2=160.0, p2=160, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 161.5, f2=161.0, p2=161, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 161.5, f2=161.0, p2=161, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 161.5, f2=161.0, p2=161, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 161.5, f2=161.0, p2=161, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 162.5, f2=162.0, p2=162, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 162.5, f2=162.0, p2=162, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 162.5, f2=162.0, p2=162, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 162.5, f2=162.0, p2=162, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 163.5, f2=163.0, p2=163, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 163.5, f2=163.0, p2=163, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 163.5, f2=163.0, p2=163, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 163.5, f2=163.0, p2=163, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 164.5, f2=164.0, p2=164, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 164.5, f2=164.0, p2=164, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 164.5, f2=164.0, p2=164, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 164.5, f2=164.0, p2=164, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 165.5, f2=165.0, p2=165, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 165.5, f2=165.0, p2=165, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 165.5, f2=165.0, p2=165, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 165.5, f2=165.0, p2=165, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 166.5, f2=166.0, p2=166, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 166.5, f2=166.0, p2=166, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 166.5, f2=166.0, p2=166, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 166.5, f2=166.0, p2=166, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 167.5, f2=167.0, p2=167, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 167.5, f2=167.0, p2=167, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 167.5, f2=167.0, p2=167, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 167.5, f2=167.0, p2=167, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 168.5, f2=168.0, p2=168, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 168.5, f2=168.0, p2=168, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 168.5, f2=168.0, p2=168, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 168.5, f2=168.0, p2=168, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 169.5, f2=169.0, p2=169, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 169.5, f2=169.0, p2=169, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 169.5, f2=169.0, p2=169, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 169.5, f2=169.0, p2=169, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 170.5, f2=170.0, p2=170, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 170.5, f2=170.0, p2=170, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 170.5, f2=170.0, p2=170, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 170.5, f2=170.0, p2=170, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 171.5, f2=171.0, p2=171, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 171.5, f2=171.0, p2=171, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 171.5, f2=171.0, p2=171, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 171.5, f2=171.0, p2=171, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 172.5, f2=172.0, p2=172, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 172.5, f2=172.0, p2=172, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 172.5, f2=172.0, p2=172, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 172.5, f2=172.0, p2=172, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 173.5, f2=173.0, p2=173, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 173.5, f2=173.0, p2=173, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 173.5, f2=173.0, p2=173, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 173.5, f2=173.0, p2=173, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 174.5, f2=174.0, p2=174, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 174.5, f2=174.0, p2=174, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 174.5, f2=174.0, p2=174, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 174.5, f2=174.0, p2=174, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 175.5, f2=175.0, p2=175, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 175.5, f2=175.0, p2=175, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 175.5, f2=175.0, p2=175, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 175.5, f2=175.0, p2=175, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 176.5, f2=176.0, p2=176, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 176.5, f2=176.0, p2=176, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 176.5, f2=176.0, p2=176, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 176.5, f2=176.0, p2=176, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 177.5, f2=177.0, p2=177, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 177.5, f2=177.0, p2=177, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 177.5, f2=177.0, p2=177, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 177.5, f2=177.0, p2=177, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 178.5, f2=178.0, p2=178, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 178.5, f2=178.0, p2=178, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 178.5, f2=178.0, p2=178, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 178.5, f2=178.0, p2=178, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 179.5, f2=179.0, p2=179, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 179.5, f2=179.0, p2=179, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 179.5, f2=179.0, p2=179, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 179.5, f2=179.0, p2=179, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 180.5, f2=180.0, p2=180, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 180.5, f2=180.0, p2=180, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 180.5, f2=180.0, p2=180, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 180.5, f2=180.0, p2=180, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 181.5, f2=181.0, p2=181, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 181.5, f2=181.0, p2=181, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 181.5, f2=181.0, p2=181, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 181.5, f2=181.0, p2=181, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 182.5, f2=182.0, p2=182, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 182.5, f2=182.0, p2=182, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 182.5, f2=182.0, p2=182, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 182.5, f2=182.0, p2=182, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 183.5, f2=183.0, p2=183, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 183.5, f2=183.0, p2=183, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 183.5, f2=183.0, p2=183, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 183.5, f2=183.0, p2=183, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 184.5, f2=184.0, p2=184, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 184.5, f2=184.0, p2=184, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 184.5, f2=184.0, p2=184, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 184.5, f2=184.0, p2=184, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 185.5, f2=185.0, p2=185, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 185.5, f2=185.0, p2=185, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 185.5, f2=185.0, p2=185, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 185.5, f2=185.0, p2=185, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 186.5, f2=186.0, p2=186, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 186.5, f2=186.0, p2=186, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 186.5, f2=186.0, p2=186, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 186.5, f2=186.0, p2=186, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 187.5, f2=187.0, p2=187, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 187.5, f2=187.0, p2=187, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 187.5, f2=187.0, p2=187, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 187.5, f2=187.0, p2=187, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 188.5, f2=188.0, p2=188, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 188.5, f2=188.0, p2=188, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 188.5, f2=188.0, p2=188, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 188.5, f2=188.0, p2=188, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 189.5, f2=189.0, p2=189, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 189.5, f2=189.0, p2=189, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 189.5, f2=189.0, p2=189, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 189.5, f2=189.0, p2=189, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 190.5, f2=190.0, p2=190, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 190.5, f2=190.0, p2=190, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 190.5, f2=190.0, p2=190, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 190.5, f2=190.0, p2=190, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 191.5, f2=191.0, p2=191, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 191.5, f2=191.0, p2=191, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 191.5, f2=191.0, p2=191, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 191.5, f2=191.0, p2=191, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 192.5, f2=192.0, p2=192, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 192.5, f2=192.0, p2=192, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 192.5, f2=192.0, p2=192, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 192.5, f2=192.0, p2=192, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 193.5, f2=193.0, p2=193, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 193.5, f2=193.0, p2=193, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 193.5, f2=193.0, p2=193, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 193.5, f2=193.0, p2=193, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 194.5, f2=194.0, p2=194, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 194.5, f2=194.0, p2=194, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 194.5, f2=194.0, p2=194, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 194.5, f2=194.0, p2=194, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 195.5, f2=195.0, p2=195, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 195.5, f2=195.0, p2=195, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 195.5, f2=195.0, p2=195, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 195.5, f2=195.0, p2=195, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 196.5, f2=196.0, p2=196, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 196.5, f2=196.0, p2=196, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 196.5, f2=196.0, p2=196, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 196.5, f2=196.0, p2=196, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 197.5, f2=197.0, p2=197, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 197.5, f2=197.0, p2=197, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 197.5, f2=197.0, p2=197, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 197.5, f2=197.0, p2=197, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 198.5, f2=198.0, p2=198, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 198.5, f2=198.0, p2=198, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 198.5, f2=198.0, p2=198, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 198.5, f2=198.0, p2=198, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 199.5, f2=199.0, p2=199, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 199.5, f2=199.0, p2=199, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 199.5, f2=199.0, p2=199, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 199.5, f2=199.0, p2=199, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 200.5, f2=200.0, p2=200, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 200.5, f2=200.0, p2=200, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 200.5, f2=200.0, p2=200, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 200.5, f2=200.0, p2=200, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 201.5, f2=201.0, p2=201, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 201.5, f2=201.0, p2=201, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 201.5, f2=201.0, p2=201, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 201.5, f2=201.0, p2=201, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 202.5, f2=202.0, p2=202, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 202.5, f2=202.0, p2=202, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 202.5, f2=202.0, p2=202, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 202.5, f2=202.0, p2=202, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 203.5, f2=203.0, p2=203, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 203.5, f2=203.0, p2=203, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 203.5, f2=203.0, p2=203, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 203.5, f2=203.0, p2=203, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 204.5, f2=204.0, p2=204, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 204.5, f2=204.0, p2=204, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 204.5, f2=204.0, p2=204, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 204.5, f2=204.0, p2=204, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 205.5, f2=205.0, p2=205, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 205.5, f2=205.0, p2=205, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 205.5, f2=205.0, p2=205, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 205.5, f2=205.0, p2=205, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 206.5, f2=206.0, p2=206, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 206.5, f2=206.0, p2=206, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 206.5, f2=206.0, p2=206, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 206.5, f2=206.0, p2=206, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 207.5, f2=207.0, p2=207, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 207.5, f2=207.0, p2=207, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 207.5, f2=207.0, p2=207, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 207.5, f2=207.0, p2=207, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 208.5, f2=208.0, p2=208, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 208.5, f2=208.0, p2=208, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 208.5, f2=208.0, p2=208, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 208.5, f2=208.0, p2=208, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 209.5, f2=209.0, p2=209, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 209.5, f2=209.0, p2=209, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 209.5, f2=209.0, p2=209, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 209.5, f2=209.0, p2=209, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 210.5, f2=210.0, p2=210, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 210.5, f2=210.0, p2=210, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 210.5, f2=210.0, p2=210, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 210.5, f2=210.0, p2=210, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 211.5, f2=211.0, p2=211, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 211.5, f2=211.0, p2=211, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 211.5, f2=211.0, p2=211, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 211.5, f2=211.0, p2=211, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 212.5, f2=212.0, p2=212, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 212.5, f2=212.0, p2=212, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 212.5, f2=212.0, p2=212, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 212.5, f2=212.0, p2=212, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 213.5, f2=213.0, p2=213, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 213.5, f2=213.0, p2=213, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 213.5, f2=213.0, p2=213, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 213.5, f2=213.0, p2=213, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 214.5, f2=214.0, p2=214, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 214.5, f2=214.0, p2=214, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 214.5, f2=214.0, p2=214, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 214.5, f2=214.0, p2=214, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 215.5, f2=215.0, p2=215, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 215.5, f2=215.0, p2=215, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 215.5, f2=215.0, p2=215, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 215.5, f2=215.0, p2=215, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 216.5, f2=216.0, p2=216, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 216.5, f2=216.0, p2=216, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 216.5, f2=216.0, p2=216, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 216.5, f2=216.0, p2=216, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 217.5, f2=217.0, p2=217, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 217.5, f2=217.0, p2=217, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 217.5, f2=217.0, p2=217, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 217.5, f2=217.0, p2=217, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 218.5, f2=218.0, p2=218, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 218.5, f2=218.0, p2=218, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 218.5, f2=218.0, p2=218, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 218.5, f2=218.0, p2=218, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 219.5, f2=219.0, p2=219, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 219.5, f2=219.0, p2=219, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 219.5, f2=219.0, p2=219, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 219.5, f2=219.0, p2=219, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 220.5, f2=220.0, p2=220, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 220.5, f2=220.0, p2=220, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 220.5, f2=220.0, p2=220, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 220.5, f2=220.0, p2=220, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 221.5, f2=221.0, p2=221, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 221.5, f2=221.0, p2=221, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 221.5, f2=221.0, p2=221, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 221.5, f2=221.0, p2=221, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 222.5, f2=222.0, p2=222, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 222.5, f2=222.0, p2=222, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 222.5, f2=222.0, p2=222, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 222.5, f2=222.0, p2=222, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 223.5, f2=223.0, p2=223, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 223.5, f2=223.0, p2=223, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 223.5, f2=223.0, p2=223, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 223.5, f2=223.0, p2=223, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 224.5, f2=224.0, p2=224, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 224.5, f2=224.0, p2=224, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 224.5, f2=224.0, p2=224, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 224.5, f2=224.0, p2=224, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 225.5, f2=225.0, p2=225, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 225.5, f2=225.0, p2=225, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 225.5, f2=225.0, p2=225, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 225.5, f2=225.0, p2=225, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 226.5, f2=226.0, p2=226, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 226.5, f2=226.0, p2=226, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 226.5, f2=226.0, p2=226, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 226.5, f2=226.0, p2=226, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 227.5, f2=227.0, p2=227, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 227.5, f2=227.0, p2=227, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 227.5, f2=227.0, p2=227, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 227.5, f2=227.0, p2=227, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 228.5, f2=228.0, p2=228, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 228.5, f2=228.0, p2=228, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 228.5, f2=228.0, p2=228, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 228.5, f2=228.0, p2=228, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 229.5, f2=229.0, p2=229, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 229.5, f2=229.0, p2=229, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 229.5, f2=229.0, p2=229, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 229.5, f2=229.0, p2=229, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 230.5, f2=230.0, p2=230, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 230.5, f2=230.0, p2=230, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 230.5, f2=230.0, p2=230, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 230.5, f2=230.0, p2=230, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 231.5, f2=231.0, p2=231, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 231.5, f2=231.0, p2=231, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 231.5, f2=231.0, p2=231, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 231.5, f2=231.0, p2=231, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 232.5, f2=232.0, p2=232, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 232.5, f2=232.0, p2=232, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 232.5, f2=232.0, p2=232, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 232.5, f2=232.0, p2=232, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 233.5, f2=233.0, p2=233, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 233.5, f2=233.0, p2=233, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 233.5, f2=233.0, p2=233, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 233.5, f2=233.0, p2=233, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 234.5, f2=234.0, p2=234, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 234.5, f2=234.0, p2=234, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 234.5, f2=234.0, p2=234, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 234.5, f2=234.0, p2=234, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 235.5, f2=235.0, p2=235, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 235.5, f2=235.0, p2=235, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 235.5, f2=235.0, p2=235, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 235.5, f2=235.0, p2=235, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 236.5, f2=236.0, p2=236, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 236.5, f2=236.0, p2=236, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 236.5, f2=236.0, p2=236, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 236.5, f2=236.0, p2=236, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 237.5, f2=237.0, p2=237, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 237.5, f2=237.0, p2=237, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 237.5, f2=237.0, p2=237, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 237.5, f2=237.0, p2=237, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 238.5, f2=238.0, p2=238, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 238.5, f2=238.0, p2=238, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 239.5, f2=239.0, p2=239, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 238.5, f2=238.0, p2=238, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 239.5, f2=239.0, p2=239, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 238.5, f2=238.0, p2=238, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 240.5, f2=240.0, p2=240, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 239.5, f2=239.0, p2=239, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 240.5, f2=240.0, p2=240, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 239.5, f2=239.0, p2=239, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 241.5, f2=241.0, p2=241, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 240.5, f2=240.0, p2=240, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 241.5, f2=241.0, p2=241, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 240.5, f2=240.0, p2=240, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 242.5, f2=242.0, p2=242, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 241.5, f2=241.0, p2=241, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 242.5, f2=242.0, p2=242, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 241.5, f2=241.0, p2=241, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 243.5, f2=243.0, p2=243, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 242.5, f2=242.0, p2=242, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 243.5, f2=243.0, p2=243, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 242.5, f2=242.0, p2=242, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 244.5, f2=244.0, p2=244, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 243.5, f2=243.0, p2=243, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 244.5, f2=244.0, p2=244, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 243.5, f2=243.0, p2=243, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 245.5, f2=245.0, p2=245, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 244.5, f2=244.0, p2=244, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 245.5, f2=245.0, p2=245, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 244.5, f2=244.0, p2=244, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 246.5, f2=246.0, p2=246, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 245.5, f2=245.0, p2=245, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 246.5, f2=246.0, p2=246, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 245.5, f2=245.0, p2=245, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 247.5, f2=247.0, p2=247, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 246.5, f2=246.0, p2=246, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 247.5, f2=247.0, p2=247, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 246.5, f2=246.0, p2=246, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 248.5, f2=248.0, p2=248, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 247.5, f2=247.0, p2=247, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 248.5, f2=248.0, p2=248, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 247.5, f2=247.0, p2=247, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 249.5, f2=249.0, p2=249, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 248.5, f2=248.0, p2=248, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 249.5, f2=249.0, p2=249, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 248.5, f2=248.0, p2=248, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 250.5, f2=250.0, p2=250, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 249.5, f2=249.0, p2=249, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 250.5, f2=250.0, p2=250, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 249.5, f2=249.0, p2=249, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 251.5, f2=251.0, p2=251, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 250.5, f2=250.0, p2=250, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 251.5, f2=251.0, p2=251, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 250.5, f2=250.0, p2=250, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 252.5, f2=252.0, p2=252, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 251.5, f2=251.0, p2=251, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 252.5, f2=252.0, p2=252, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 251.5, f2=251.0, p2=251, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 253.5, f2=253.0, p2=253, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 252.5, f2=252.0, p2=252, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 253.5, f2=253.0, p2=253, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 252.5, f2=252.0, p2=252, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 254.5, f2=254.0, p2=254, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 253.5, f2=253.0, p2=253, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 254.5, f2=254.0, p2=254, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 253.5, f2=253.0, p2=253, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 255.5, f2=255.0, p2=255, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 254.5, f2=254.0, p2=254, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 255.5, f2=255.0, p2=255, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 254.5, f2=254.0, p2=254, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 129.5, f2=129.0, p2=129, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 255.5, f2=255.0, p2=255, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 129.5, f2=129.0, p2=129, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 255.5, f2=255.0, p2=255, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 130.5, f2=130.0, p2=130, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 129.5, f2=129.0, p2=129, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 130.5, f2=130.0, p2=130, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 131.5, f2=131.0, p2=131, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 129.5, f2=129.0, p2=129, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 130.5, f2=130.0, p2=130, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 131.5, f2=131.0, p2=131, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 132.5, f2=132.0, p2=132, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 130.5, f2=130.0, p2=130, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 131.5, f2=131.0, p2=131, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 132.5, f2=132.0, p2=132, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 133.5, f2=133.0, p2=133, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 131.5, f2=131.0, p2=131, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 132.5, f2=132.0, p2=132, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 133.5, f2=133.0, p2=133, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 134.5, f2=134.0, p2=134, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 132.5, f2=132.0, p2=132, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 133.5, f2=133.0, p2=133, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 134.5, f2=134.0, p2=134, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 135.5, f2=135.0, p2=135, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 133.5, f2=133.0, p2=133, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 134.5, f2=134.0, p2=134, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 135.5, f2=135.0, p2=135, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 136.5, f2=136.0, p2=136, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 134.5, f2=134.0, p2=134, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 135.5, f2=135.0, p2=135, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 136.5, f2=136.0, p2=136, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 137.5, f2=137.0, p2=137, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 135.5, f2=135.0, p2=135, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 136.5, f2=136.0, p2=136, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 137.5, f2=137.0, p2=137, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 138.5, f2=138.0, p2=138, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 136.5, f2=136.0, p2=136, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 137.5, f2=137.0, p2=137, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 139.5, f2=139.0, p2=139, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 138.5, f2=138.0, p2=138, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 138.5, f2=138.0, p2=138, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 137.5, f2=137.0, p2=137, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 140.5, f2=140.0, p2=140, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 139.5, f2=139.0, p2=139, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 139.5, f2=139.0, p2=139, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 138.5, f2=138.0, p2=138, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 141.5, f2=141.0, p2=141, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 140.5, f2=140.0, p2=140, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 140.5, f2=140.0, p2=140, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 139.5, f2=139.0, p2=139, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 142.5, f2=142.0, p2=142, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 141.5, f2=141.0, p2=141, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 141.5, f2=141.0, p2=141, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 140.5, f2=140.0, p2=140, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 143.5, f2=143.0, p2=143, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 142.5, f2=142.0, p2=142, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 142.5, f2=142.0, p2=142, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 141.5, f2=141.0, p2=141, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 144.5, f2=144.0, p2=144, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 143.5, f2=143.0, p2=143, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 143.5, f2=143.0, p2=143, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 142.5, f2=142.0, p2=142, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 145.5, f2=145.0, p2=145, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 144.5, f2=144.0, p2=144, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 144.5, f2=144.0, p2=144, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 143.5, f2=143.0, p2=143, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 146.5, f2=146.0, p2=146, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 145.5, f2=145.0, p2=145, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 145.5, f2=145.0, p2=145, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 144.5, f2=144.0, p2=144, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 147.5, f2=147.0, p2=147, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 146.5, f2=146.0, p2=146, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 146.5, f2=146.0, p2=146, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 145.5, f2=145.0, p2=145, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 148.5, f2=148.0, p2=148, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 147.5, f2=147.0, p2=147, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 147.5, f2=147.0, p2=147, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 146.5, f2=146.0, p2=146, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 149.5, f2=149.0, p2=149, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 148.5, f2=148.0, p2=148, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 148.5, f2=148.0, p2=148, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 147.5, f2=147.0, p2=147, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 150.5, f2=150.0, p2=150, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 149.5, f2=149.0, p2=149, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 149.5, f2=149.0, p2=149, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 148.5, f2=148.0, p2=148, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 151.5, f2=151.0, p2=151, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 150.5, f2=150.0, p2=150, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 150.5, f2=150.0, p2=150, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 149.5, f2=149.0, p2=149, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 152.5, f2=152.0, p2=152, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 151.5, f2=151.0, p2=151, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 151.5, f2=151.0, p2=151, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 150.5, f2=150.0, p2=150, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 153.5, f2=153.0, p2=153, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 152.5, f2=152.0, p2=152, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 152.5, f2=152.0, p2=152, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 151.5, f2=151.0, p2=151, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 154.5, f2=154.0, p2=154, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 153.5, f2=153.0, p2=153, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 153.5, f2=153.0, p2=153, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 152.5, f2=152.0, p2=152, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 155.5, f2=155.0, p2=155, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 154.5, f2=154.0, p2=154, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 154.5, f2=154.0, p2=154, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 153.5, f2=153.0, p2=153, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 156.5, f2=156.0, p2=156, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 155.5, f2=155.0, p2=155, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 155.5, f2=155.0, p2=155, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 154.5, f2=154.0, p2=154, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 157.5, f2=157.0, p2=157, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 156.5, f2=156.0, p2=156, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 156.5, f2=156.0, p2=156, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 155.5, f2=155.0, p2=155, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 158.5, f2=158.0, p2=158, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 157.5, f2=157.0, p2=157, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 157.5, f2=157.0, p2=157, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 156.5, f2=156.0, p2=156, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 159.5, f2=159.0, p2=159, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 158.5, f2=158.0, p2=158, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 158.5, f2=158.0, p2=158, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 157.5, f2=157.0, p2=157, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 160.5, f2=160.0, p2=160, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 159.5, f2=159.0, p2=159, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 158.5, f2=158.0, p2=158, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 159.5, f2=159.0, p2=159, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 161.5, f2=161.0, p2=161, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 160.5, f2=160.0, p2=160, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 159.5, f2=159.0, p2=159, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 160.5, f2=160.0, p2=160, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 162.5, f2=162.0, p2=162, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 161.5, f2=161.0, p2=161, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 160.5, f2=160.0, p2=160, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 161.5, f2=161.0, p2=161, delta2=0.5
# ...
# WARNING:bilinear:Overflow on dim2: d2= 167.5, f2=167.0, p2=167, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 179.5, f2=179.0, p2=179, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 165.5, f2=165.0, p2=165, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 173.5, f2=173.0, p2=173, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 168.5, f2=168.0, p2=168, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 180.5, f2=180.0, p2=180, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 166.5, f2=166.0, p2=166, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 174.5, f2=174.0, p2=174, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 169.5, f2=169.0, p2=169, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 181.5, f2=181.0, p2=181, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 167.5, f2=167.0, p2=167, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 175.5, f2=175.0, p2=175, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 170.5, f2=170.0, p2=170, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 182.5, f2=182.0, p2=182, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 168.5, f2=168.0, p2=168, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 176.5, f2=176.0, p2=176, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 171.5, f2=171.0, p2=171, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 183.5, f2=183.0, p2=183, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 169.5, f2=169.0, p2=169, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 177.5, f2=177.0, p2=177, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 172.5, f2=172.0, p2=172, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 184.5, f2=184.0, p2=184, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 170.5, f2=170.0, p2=170, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 178.5, f2=178.0, p2=178, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 173.5, f2=173.0, p2=173, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 185.5, f2=185.0, p2=185, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 171.5, f2=171.0, p2=171, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 179.5, f2=179.0, p2=179, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 174.5, f2=174.0, p2=174, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 186.5, f2=186.0, p2=186, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 172.5, f2=172.0, p2=172, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 180.5, f2=180.0, p2=180, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 175.5, f2=175.0, p2=175, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 187.5, f2=187.0, p2=187, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 173.5, f2=173.0, p2=173, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 181.5, f2=181.0, p2=181, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 176.5, f2=176.0, p2=176, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 188.5, f2=188.0, p2=188, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 174.5, f2=174.0, p2=174, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 182.5, f2=182.0, p2=182, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 177.5, f2=177.0, p2=177, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 189.5, f2=189.0, p2=189, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 175.5, f2=175.0, p2=175, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 183.5, f2=183.0, p2=183, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 178.5, f2=178.0, p2=178, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 190.5, f2=190.0, p2=190, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 176.5, f2=176.0, p2=176, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 184.5, f2=184.0, p2=184, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 179.5, f2=179.0, p2=179, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 191.5, f2=191.0, p2=191, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 177.5, f2=177.0, p2=177, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 185.5, f2=185.0, p2=185, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 180.5, f2=180.0, p2=180, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 192.5, f2=192.0, p2=192, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 178.5, f2=178.0, p2=178, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 186.5, f2=186.0, p2=186, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 181.5, f2=181.0, p2=181, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 193.5, f2=193.0, p2=193, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 179.5, f2=179.0, p2=179, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 187.5, f2=187.0, p2=187, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 182.5, f2=182.0, p2=182, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 194.5, f2=194.0, p2=194, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 180.5, f2=180.0, p2=180, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 188.5, f2=188.0, p2=188, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 183.5, f2=183.0, p2=183, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 195.5, f2=195.0, p2=195, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 181.5, f2=181.0, p2=181, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 189.5, f2=189.0, p2=189, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 184.5, f2=184.0, p2=184, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 196.5, f2=196.0, p2=196, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 182.5, f2=182.0, p2=182, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 190.5, f2=190.0, p2=190, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 185.5, f2=185.0, p2=185, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 197.5, f2=197.0, p2=197, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 183.5, f2=183.0, p2=183, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 191.5, f2=191.0, p2=191, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 186.5, f2=186.0, p2=186, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 198.5, f2=198.0, p2=198, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 184.5, f2=184.0, p2=184, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 192.5, f2=192.0, p2=192, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 187.5, f2=187.0, p2=187, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 199.5, f2=199.0, p2=199, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 185.5, f2=185.0, p2=185, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 193.5, f2=193.0, p2=193, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 188.5, f2=188.0, p2=188, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 200.5, f2=200.0, p2=200, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 186.5, f2=186.0, p2=186, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 194.5, f2=194.0, p2=194, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 189.5, f2=189.0, p2=189, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 201.5, f2=201.0, p2=201, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 187.5, f2=187.0, p2=187, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 195.5, f2=195.0, p2=195, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 190.5, f2=190.0, p2=190, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 202.5, f2=202.0, p2=202, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 188.5, f2=188.0, p2=188, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 196.5, f2=196.0, p2=196, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 191.5, f2=191.0, p2=191, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 203.5, f2=203.0, p2=203, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 189.5, f2=189.0, p2=189, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 197.5, f2=197.0, p2=197, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 192.5, f2=192.0, p2=192, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 204.5, f2=204.0, p2=204, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 190.5, f2=190.0, p2=190, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 198.5, f2=198.0, p2=198, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 193.5, f2=193.0, p2=193, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 205.5, f2=205.0, p2=205, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 191.5, f2=191.0, p2=191, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 199.5, f2=199.0, p2=199, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 194.5, f2=194.0, p2=194, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 206.5, f2=206.0, p2=206, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 192.5, f2=192.0, p2=192, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 200.5, f2=200.0, p2=200, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 195.5, f2=195.0, p2=195, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 207.5, f2=207.0, p2=207, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 193.5, f2=193.0, p2=193, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 201.5, f2=201.0, p2=201, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 196.5, f2=196.0, p2=196, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 208.5, f2=208.0, p2=208, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 194.5, f2=194.0, p2=194, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 202.5, f2=202.0, p2=202, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 197.5, f2=197.0, p2=197, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 209.5, f2=209.0, p2=209, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 195.5, f2=195.0, p2=195, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 203.5, f2=203.0, p2=203, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 198.5, f2=198.0, p2=198, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 210.5, f2=210.0, p2=210, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 196.5, f2=196.0, p2=196, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 204.5, f2=204.0, p2=204, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 199.5, f2=199.0, p2=199, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 211.5, f2=211.0, p2=211, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 197.5, f2=197.0, p2=197, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 205.5, f2=205.0, p2=205, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 200.5, f2=200.0, p2=200, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 212.5, f2=212.0, p2=212, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 198.5, f2=198.0, p2=198, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 206.5, f2=206.0, p2=206, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 201.5, f2=201.0, p2=201, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 213.5, f2=213.0, p2=213, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 199.5, f2=199.0, p2=199, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 207.5, f2=207.0, p2=207, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 202.5, f2=202.0, p2=202, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 214.5, f2=214.0, p2=214, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 200.5, f2=200.0, p2=200, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 208.5, f2=208.0, p2=208, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 203.5, f2=203.0, p2=203, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 215.5, f2=215.0, p2=215, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 209.5, f2=209.0, p2=209, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 201.5, f2=201.0, p2=201, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 204.5, f2=204.0, p2=204, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 216.5, f2=216.0, p2=216, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 210.5, f2=210.0, p2=210, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 202.5, f2=202.0, p2=202, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 205.5, f2=205.0, p2=205, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 217.5, f2=217.0, p2=217, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 211.5, f2=211.0, p2=211, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 203.5, f2=203.0, p2=203, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 206.5, f2=206.0, p2=206, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 218.5, f2=218.0, p2=218, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 212.5, f2=212.0, p2=212, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 204.5, f2=204.0, p2=204, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 207.5, f2=207.0, p2=207, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 219.5, f2=219.0, p2=219, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 213.5, f2=213.0, p2=213, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 205.5, f2=205.0, p2=205, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 208.5, f2=208.0, p2=208, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 220.5, f2=220.0, p2=220, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 214.5, f2=214.0, p2=214, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 206.5, f2=206.0, p2=206, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 209.5, f2=209.0, p2=209, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 221.5, f2=221.0, p2=221, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 215.5, f2=215.0, p2=215, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 207.5, f2=207.0, p2=207, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 210.5, f2=210.0, p2=210, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 222.5, f2=222.0, p2=222, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 216.5, f2=216.0, p2=216, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 208.5, f2=208.0, p2=208, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 211.5, f2=211.0, p2=211, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 223.5, f2=223.0, p2=223, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 217.5, f2=217.0, p2=217, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 218.5, f2=218.0, p2=218, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 212.5, f2=212.0, p2=212, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 224.5, f2=224.0, p2=224, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 209.5, f2=209.0, p2=209, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 219.5, f2=219.0, p2=219, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 213.5, f2=213.0, p2=213, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 225.5, f2=225.0, p2=225, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 210.5, f2=210.0, p2=210, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 220.5, f2=220.0, p2=220, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 214.5, f2=214.0, p2=214, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 226.5, f2=226.0, p2=226, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 211.5, f2=211.0, p2=211, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 221.5, f2=221.0, p2=221, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 215.5, f2=215.0, p2=215, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 227.5, f2=227.0, p2=227, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 212.5, f2=212.0, p2=212, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 222.5, f2=222.0, p2=222, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 216.5, f2=216.0, p2=216, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 228.5, f2=228.0, p2=228, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 213.5, f2=213.0, p2=213, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 223.5, f2=223.0, p2=223, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 217.5, f2=217.0, p2=217, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 229.5, f2=229.0, p2=229, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 214.5, f2=214.0, p2=214, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 224.5, f2=224.0, p2=224, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 218.5, f2=218.0, p2=218, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 230.5, f2=230.0, p2=230, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 215.5, f2=215.0, p2=215, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 225.5, f2=225.0, p2=225, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 219.5, f2=219.0, p2=219, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 231.5, f2=231.0, p2=231, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 216.5, f2=216.0, p2=216, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 226.5, f2=226.0, p2=226, delta2=0.5
# WARNING:bilinear:Overflow on dim2: d2= 220.5, f2=220.0, p2=220, delta2=0.5

# %%
from extra_data import RunDirectory
from extra

run_red = RunDirectory("/gpfs/exfel/exp/SPB/202304/p003378/red/r0510")
run_raw = RunDirectory("/gpfs/exfel/exp/SPB/202304/p003378/raw/r0510")

# %%
run_red.info()
# Out:
# # of trains:    3085
# Duration:       0:05:08.5
# First train ID: 1662615691
# Last train ID:  1662618775
#
# 16 XTDF detector modules of SPB_DET_AGIPD1M-1/DET/*
#   e.g. module 0 : 512 x 128 pixels
#   SPB_DET_AGIPD1M-1/DET/0CH0:xtdf
#   5 frames per train, up to 15425 frames total
#
# 0 instrument sources (excluding XTDF detectors):
#
# 0 control sources:

# %%
run_raw.info()
# Out:
# # of trains:    3085
# Duration:       0:05:08.5
# First train ID: 1662615691
# Last train ID:  1662618775
#
# 16 XTDF detector modules of SPB_DET_AGIPD1M-1/DET/*
#   e.g. module 0 : 512 x 128 pixels
#   SPB_DET_AGIPD1M-1/DET/0CH0:xtdf
#   352 frames per train, up to 1085920 frames total
#
# 12 instrument sources (excluding XTDF detectors):
#   - SA1_XTD2_XGM/XGM/DOOCS:output
#   - SPB_EHD_IBS/CAM/1:daqOutput
#   - SPB_EXP_SYS/TSYS/TIMESERVER:outputBunchPattern
#   - SPB_EXP_ZYLA/CAM/1:daqOutput
#   - SPB_IRU_AGIPD1M1/REDU/LITFRM:output
#   - SPB_LAS_SYS/ADC/ADQ1:network
#   - SPB_LAS_SYS/ADC/UTC1-1:channel_0.output
#   - SPB_LAS_SYS/ADC/UTC1-1:channel_1.output
#   - SPB_LAS_SYS/ADC/UTC1-1:channel_2.output
#   - SPB_LAS_SYS/ADC/UTC1-1:channel_3.output
#   - SPB_RR_SYS/TSYS/X2TIMER2:outputBunchPattern
#   - SPB_XTD9_XGM/XGM/DOOCS:output
#
# 42 control sources:
#   - ACC_SYS_DOOCS/CTRL/BEAMCONDITIONS
#   - SA1_XTD2_ATT/MDL/MAIN
#   - SA1_XTD2_XGM/XGM/DOOCS
#   - SPB_BIO_SYS/PUMP/HPLC
#   - SPB_DET_AGIPD1M-1/CC/MON_0
#   - SPB_EXP_SYS/FUNGEN/AFG31052-1
#   - SPB_EXP_SYS/TSYS/UTC_1_S3
#   - SPB_EXP_ZYLA/CAM/1
#   - SPB_IRU_AGIPD1M/MOTOR/Z_STEPPER
#   - SPB_IRU_AGIPD1M/PSC/HV
#   - SPB_IRU_AGIPD1M/TSENS/H1_T_EXTHOUS
#   - SPB_IRU_AGIPD1M/TSENS/H2_T_EXTHOUS
#   - SPB_IRU_AGIPD1M/TSENS/Q1_T_BLOCK
#   - SPB_IRU_AGIPD1M/TSENS/Q2_T_BLOCK
#   - SPB_IRU_AGIPD1M/TSENS/Q3_T_BLOCK
#   - SPB_IRU_AGIPD1M/TSENS/Q4_T_BLOCK
#   - SPB_IRU_AGIPD1M1/CTRL/MC1
#   - SPB_IRU_AGIPD1M1/CTRL/MC2
#   - SPB_IRU_AGIPD1M1/FPGA/MASTER_H1
#   - SPB_IRU_AGIPD1M1/FPGA/MASTER_H2
#   - SPB_IRU_AGIPD1M1/MDL/DATA_SELECTOR
#   - SPB_IRU_AGIPD1M1/MDL/FPGA_COMP
#   - SPB_IRU_AGIPD1M1/REDU/LITFRM
#   - SPB_IRU_LIQUIDJET/FLOW/BRONKHORST_1
#   - SPB_IRU_LIQUIDJET/FLOW/BRONKHORST_SAMPLE1
#   - SPB_IRU_LIQUIDJET/FLOW/BRONKHORST_SAMPLE2
#   - SPB_IRU_LIQUIDJET/FLOW/BRONKHORST_WASH1
#   - SPB_IRU_LIQUIDJET/FLOW/BRONKHORST_WASH2
#   - SPB_IRU_LIQUIDJET/MDL/MANIFOLD_VALVES
#   - SPB_IRU_LIQUIDJET/VALVE/VALVE_SAMPLE_1
#   - SPB_IRU_LIQUIDJET/VALVE/VALVE_SAMPLE_2
#   - SPB_IRU_LIQUIDJET/VALVE/VALVE_SAMPLE_3
#   - SPB_IRU_LIQUIDJET/VALVE/VALVE_SAMPLE_4
#   - SPB_IRU_MOTORS/MDL/DATA_SELECT
#   - SPB_IRU_VAC/GAUGE/GAUGE_FR_6
#   - SPB_LAS_SYS/ADC/ADQ1
#   - SPB_LAS_SYS/ADC/UTC1-1
#   - SPB_RR_SYS/MDL/BUNCH_PATTERN
#   - SPB_RR_SYS/TSYS/X2TIMER2
#   - SPB_XTD2_UND/DOOCS/ENERGY
#   - SPB_XTD9_ATT/MDL/MAIN
#   - SPB_XTD9_XGM/XGM/DOOCS
